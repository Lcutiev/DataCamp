# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips.total_bill, tips.tip)
sns.set_style('darkgrid')
plt.show()

# %% [markdown]
# ### **1. Biểu độ xu hướng**

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips, markers=['o', 'x'], palette='Set1', legend=True)

# %% [markdown]
# ### **2.Biểu đồ phân bố**

# %%
sns.violinplot(y=tips['total_bill'], palette='coolwarm')
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
# Sự phân bố total_bill theo ngày
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Kết luận**:
# - Thứ 7 có nhiều loại khách hàng hơn
# - Khách hàng có xu hướng chi tiêu nhiều hơn vào cuối tuần

# %%
# Sự phân bố

# %%
Thứ 6 có sự khác biệt giữa 2 nhóm hút thuốc và không hút thuốc
- Nhóm không hút thuốc chi nhiều hoá đơn hơn: Giao động dữ liệu cao hơn
- Nhóm hút thuốc đa dạng hoá đơn

# %%
sns.violinplot(x='day', y='total_bill', hue='smoker',data=tips, palette='muted', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
# Kiểm soát thứ tự các violinplot bằng cách truyền  một thứ tự nhãn cụ thể
sns.violinplot(x='time', y='total_bill', hue='smoker',data=tips, order=['Lunch', 'Dinner'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ### **3.Biểu đồ tần số**

# %%
# Hiển thị tần số của mỗi loại giới tính trong bộ dữ liệu
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Nếu không dùng seaborn, thiết lập nhiều tham số
female = tips[tips.sex == 'Female']['sex'].count()
male = tips[tips.sex == 'Male']['sex'].count()

# %%
plt.bar(['Male', 'Female'], [male, female])
plt.show()

# %% [markdown]
# **Kết luận:**
# - Số lượng nam gấp đôi nữ, có thể là quán bia

# %%
# Hiển thị số lượng theo phân loại
sns.countplot(x='sex', hue='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Vẽ biểu đồ theo chiều ngang
# Đổi giá trị x thành y, xoay 90 độ
sns.countplot(y='sex', hue='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %% [markdown]
# ### **4.Biểu đồ heatmap**

# %%
import numpy as np
uniform_data = np.random.rand(10, 12)
uniform_data
# Out:
# array([[0.49992772, 0.24735656, 0.83820358, 0.40140731, 0.23604038,
#         0.46721081, 0.67305218, 0.44391845, 0.36476131, 0.22819846,
#         0.45929038, 0.8765767 ],
#        [0.21031937, 0.89818932, 0.80760814, 0.3496836 , 0.53393955,
#         0.02296619, 0.34339627, 0.49121105, 0.75243064, 0.30294927,
#         0.52772099, 0.62274071],
#        [0.17134315, 0.05971578, 0.38565945, 0.63116435, 0.71681805,
#         0.25751288, 0.33115912, 0.79325712, 0.84623184, 0.35230816,
#         0.32353995, 0.23632197],
#        [0.12538199, 0.76186548, 0.35413436, 0.14081871, 0.07494689,
#         0.61651365, 0.75005851, 0.22935252, 0.38269301, 0.69534866,
#         0.68251184, 0.09280829],
#        [0.00833588, 0.7590463 , 0.43754635, 0.93973767, 0.98328936,
#         0.45317837, 0.85467986, 0.38879398, 0.39981627, 0.08936092,
#         0.15136396, 0.6339733 ],
#        [0.74233127, 0.11631585, 0.69634944, 0.9695376 , 0.80928944,
#         0.10911296, 0.50745657, 0.53578071, 0.96521329, 0.84661727,
#         0.17430624, 0.01224201],
#        [0.9756861 , 0.41826614, 0.23438611, 0.80482098, 0.3248339 ,
#         0.65838905, 0.93860742, 0.36575888, 0.24414191, 0.13847534,
#         0.64033172, 0.29876919],
#        [0.46548119, 0.41096821, 0.33809289, 0.85516432, 0.73943925,
#         0.40403074, 0.62215137, 0.62130079, 0.22903091, 0.13501301,
#         0.38819988, 0.21387602],
#        [0.16981377, 0.80551711, 0.71783423, 0.00617401, 0.57602247,
#         0.06910413, 0.1549977 , 0.24624668, 0.93566016, 0.60378579,
#         0.12881842, 0.92788128],
#        [0.57913317, 0.2539831 , 0.34772281, 0.35468523, 0.44479151,
#         0.1076479 , 0.48759789, 0.56738243, 0.81953993, 0.3006191 ,
#         0.78551727, 0.77806645]])

# %%
sns.heatmap(uniform_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Kết luận:**
# - Biểu độ màu cho thấy sự phân bố dữ liệu, giá trị to nhỏ của dữ liệu
# - Thanh bar map bên phải: càng đen giá trị càng nhỏ, càng nhạt giá trị càng lớn gần bằng 1

# %%
# Thay đổi giới hạn màu sắc
sns.heatmap(uniform_data, vmin=0, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **5. Biểu đồ Box plot**

# %%
# Vẽ biểu đồ box plot cho thuộc tính total_bill
# Boxplot: Không cho thấy tần suất xuất hiện nhưng cho thấy giá trị ngoại lai
# Ví dụ: số ít khách hàng chi bill trên 40, không đại diện cho số đông
sns.boxplot(x=tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# Vẽ phân nhóm theo ngày

# %%
# Phân loại theo nhiều nhóm
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette='Set3')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', hue='time', data=tips, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
Biểu đồ cặp

# %%
# Sử dụng pairlot với dữ liệu ít vì nó xây dựng tốn nhiều tài nguyên, thừa dữ liệu dựng 1 loạt biểu đồ
sns.pairplot(tips, hue='sex')

# %%
Biểu đồ 1: total_bill vs sex: nam chi nhiều hơn nữ

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.pairplot(tips, hue='day')

# %%
pwd
# Out:
# '/Users/lynnvan/DataCamp'
