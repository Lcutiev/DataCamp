# %% [markdown]
# ## **MẢNG ĐỒ THỊ**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
students = pd.read_csv('students.csv')
students.head()
# Out:
#    Mã học sinh            Họ tên   Ngày sinh Giới tính    Quê quán  Toán   Lý  \
# 0     20205210   Nguyễn Đức Bình   3/10/2000       Nam      Hà Nội   7.0  8.0
# 1     20205211     Lê Minh Hoàng   2/11/2001       Nam  Quảng Bình   5.6  7.7
# 2     20205212  Trần Trang Nhung    7/5/2002        Nữ      Hà Nam   4.2  6.5
# 3     20205213   Nguyễn Thị Linh  12/17/2000        Nữ    Bắc Ninh   8.0  5.6
# 4     20205214     Đặng Ngọc Sơn   1/25/2000       Nam   Thái Bình   9.3  5.8
#
#    Hoá  Sinh  Văn   Sử  Địa  Tiếng Anh
# 0  8.8   6.8  4.0  5.4  5.6        8.5
# 1  6.0   7.0  6.5  6.0  3.4        9.0
# 2  5.4   8.0  7.0  7.5  4.3        5.5
# 3  6.5   7.0  7.5  6.5  5.6        6.0
# 4  7.5   4.5  6.5  4.5  7.8        3.8

# %% [markdown]
# ![image.png](attachment:964d5b7f-4bcb-482a-885f-00c0a5013cb0.png)

# %%
plt.plot(students.index, students['Toán'], color='r', label='Toán')
plt.plot(students.index, students['Lý'], color='b', label='Lý')
plt.plot(students.index, students['Hoá'], color='y', label='Hoá')
fig = plt.gcf()
fig.set_size_inches(18.5, 6.5)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.legend(fontsize=14, loc='lower right')
plt.show()

# %% [markdown]
# ![image.png](attachment:47a03f22-2059-4b77-bcb2-9ec89927bae1.png)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(students.index, students['Toán'], color='r', label='Toán')
ax[0].plot(students.index, students['Lý'], color='b', label='Lý')
ax[0].plot(students.index, students['Hoá'], color='y', label='Hoá')
ax[0].set_ylabel('Khối A', fontsize=14)
ax[0].legend(fontsize=14, loc='lower right')

ax[1].plot(students.index, students['Văn'], color='r', label='Văn')
ax[1].plot(students.index, students['Sử'], color='b', label='Sử')
ax[1].plot(students.index, students['Địa'], color='y', label='Địa')
ax[1].set_ylabel('Khối C', fontsize=14)
ax[1].legend(fontsize=14, loc='lower right')

fig.set_size_inches(18.5, 6.5)
plt.show()

# %% [markdown]
# ![image.png](attachment:9addc0ab-ccfa-44b1-b70b-d04fad7216de.png)

# %% [markdown]
# ![image.png](attachment:e13599e6-ce95-4784-a98f-65e7c3980bbf.png)

# %%
tva = ['Toán', 'Văn', 'Tiếng Anh']
lhssd = ['Lý', 'Hoá', 'Sinh', 'Sử', 'Địa']
students['Trung bình'] = round((students[tva].sum(axis=1) * 2 + students[lhssd].sum(axis=1)) / 11)
students
# Out:
#     Mã học sinh                Họ tên   Ngày sinh Giới tính     Quê quán  \
# 0      20205210       Nguyễn Đức Bình   3/10/2000       Nam       Hà Nội
# 1      20205211         Lê Minh Hoàng   2/11/2001       Nam   Quảng Bình
# 2      20205212      Trần Trang Nhung    7/5/2002        Nữ       Hà Nam
# 3      20205213       Nguyễn Thị Linh  12/17/2000        Nữ     Bắc Ninh
# 4      20205214         Đặng Ngọc Sơn   1/25/2000       Nam    Thái Bình
# 5      20205215         Hà Trung Kiên    4/3/2000       Nam       Hà Nội
# 6      20205216          Võ Hoàng Yến   6/21/2000        Nữ     Nam Định
# 7      20205217       Hoàng Trung Sơn   8/27/2000       Nam     Bắc Ninh
# 8      20205218      Nguyễn Văn Thành   5/20/2000       Nam       Hà Nội
# 9      20205219      Nguyễn Thanh Oai   5/25/2000       Nam       Hà Nội
# 10     20205220      Nguyễn Trọng Thọ    2/3/2000       Nam  Tuyên Quang
# 11     20205221         Lương Thị Hoa    3/4/2001        Nữ     Bắc Ninh
# 12     20205222      Nguyễn Quang Huy   2/17/2000       Nam  Thái Nguyên
# 13     20205223           Lê Bá Giang    5/6/2001       Nam  Thái Nguyên
# 14     20205224          Hà Thị Tuyết   8/17/2001        Nữ     Hà Giang
# 15     20205225          Võ Trọng Kim   6/22/2000       Nam    Thái Bình
# 16     20205226        Trần Tuyết Mai   9/20/2000        Nữ   Quảng Ninh
# 17     20205227  Nguyễn Thị Thuỳ Dung   12/2/2001        Nữ   Quảng Bình
# 18     20205228        Bùi Văn Trường  12/31/2000       Nam     Nam Định
# 19     20205229            Vũ Văn Đức    4/6/2000       Nam       Hà Nội
# 20     20205230          Hồ Văn Quyết   8/12/2000       Nam     Hà Giang
#
#     Toán   Lý  Hoá  Sinh   Văn    Sử  Địa  Tiếng Anh  Trung bình
# 0    7.0  8.0  8.8   6.8   4.0   5.4  5.6        8.5         7.0
# 1    5.6  7.7  6.0   7.0   6.5   6.0  3.4        9.0         7.0
# 2    4.2  6.5  5.4   8.0   7.0   7.5  4.3        5.5         6.0
# 3    8.0  5.6  6.5   7.0   7.5   6.5  5.6        6.0         7.0
# 4    9.3  5.8  7.5   4.5   6.5   4.5  7.8        3.8         6.0
# 5    5.6  7.0  5.6   5.0   6.4   3.8  8.0        4.9         6.0
# 6    6.7  6.8  7.3   6.0   6.7   8.0  9.5        7.6         7.0
# 7    7.5  9.0  7.0   2.0   5.2   2.0  7.0        6.5         6.0
# 8    7.0  7.4  6.4   9.0   8.5   9.2  8.4        7.8         8.0
# 9    8.2  7.0  8.7   6.5   4.8   4.6  4.8        5.5         6.0
# 10   6.5  5.5  5.4   3.0  10.0   5.0  8.0        7.0         7.0
# 11   7.3  9.0  7.6   5.6   6.0   4.0  8.0        2.0         6.0
# 12   2.5  3.6  9.2   8.0   3.1   3.0  3.0        6.0         5.0
# 13   3.7  5.0  3.0   3.4   2.0  10.0  6.0        6.0         5.0
# 14   9.0  5.0  6.0   5.0   6.0   6.0  4.0       10.0         7.0
# 15   8.5  6.8  4.0   2.8   5.4   9.0  5.0        3.0         6.0
# 16   4.5  5.0  5.0   4.0   5.0   7.4  8.5        2.0         5.0
# 17   6.5  2.0  6.5   5.0   5.0   9.0  5.4        6.0         6.0
# 18   7.2  5.0  6.0   9.0   8.0   5.5  9.0        7.0         7.0
# 19   3.2  9.0  6.0   9.0   3.0   9.0  3.0        9.0         6.0
# 20   1.0  2.0  9.4   4.5   5.6   7.0  8.0        9.0         6.0

# %%
gioi = students[students['Toán'] >=8]['Mã học sinh'].count()
kha = students[(students['Toán'] < 8) & (students['Toán'] >=6.5)]['Mã học sinh'].count()
tb = students[(students['Toán'] < 6.5) & (students['Toán'] >=5)]['Mã học sinh'].count()
kem = students[students['Toán'] < 5]['Mã học sinh'].count()

# %%
fig, ax = plt.subplots(1,2)
ax[0].bar(students.index, students['Trung bình'], label='Điểm TB', width = 0.5)
ax[0].set_ylabel('Thang điểm 10', fontsize=14)
ax[0].legend(loc='upper right')
ax[0].set_title('Điểm TB', fontsize=14)
ax[0].tick_params(axis='both', size=14)

scores = [gioi, kha, tb, kem]
labels = ['Giỏi', 'Khá', 'Trung bình', 'Kém']
ax[1].pie(scores, labels=labels, autopct='%1.2f%%')
ax[1].set_title('Xếp loại chung điểm Toán', fontsize=14)

fig.set_size_inches(18.5, 6.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **Giới thiệu thư viện seaborn**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Database in seaborn
# Phổ biến: iris, titanic
sns.get_dataset_names()

# %%
tips = sns.load_dataset('tips')
tips.head()
