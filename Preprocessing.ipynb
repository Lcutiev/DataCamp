# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder

# %%
volunteer = pd.read_csv('volunteer_opportunities.csv')

# %%
volunteer.head()
# Out:
#    opportunity_id  content_id  vol_requests  event_time  \
# 0            4996       37004            50           0
# 1            5008       37036             2           0
# 2            5016       37143            20           0
# 3            5022       37237           500           0
# 4            5055       37425            15           0
#
#                                                title  hits  \
# 0  Volunteers Needed For Rise Up & Stay Put! Home...   737
# 1                                       Web designer    22
# 2      Urban Adventures - Ice Skating at Lasker Rink    62
# 3  Fight global hunger and support women farmers ...    14
# 4                                      Stop 'N' Swap    31
#
#                                              summary is_priority  category_id  \
# 0  Building on successful events last summer and ...         NaN          NaN
# 1             Build a website for an Afghan business         NaN          1.0
# 2  Please join us and the students from Mott Hall...         NaN          1.0
# 3  The Oxfam Action Corps is a group of dedicated...         NaN          1.0
# 4  Stop 'N' Swap reduces NYC's waste by finding n...         NaN          4.0
#
#                category_desc  ...     end_date_date    status Latitude  \
# 0                        NaN  ...      July 30 2011  approved      NaN
# 1  Strengthening Communities  ...  February 01 2011  approved      NaN
# 2  Strengthening Communities  ...   January 29 2011  approved      NaN
# 3  Strengthening Communities  ...     March 31 2012  approved      NaN
# 4                Environment  ...  February 05 2011  approved      NaN
#
#    Longitude  Community Board Community Council  Census Tract  BIN  BBL NTA
# 0        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 1        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 2        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 3        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 4        NaN              NaN                NaN          NaN  NaN  NaN NaN
#
# [5 rows x 35 columns]

# %%
volunteer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   opportunity_id      665 non-null    int64
#  1   content_id          665 non-null    int64
#  2   vol_requests        665 non-null    int64
#  3   event_time          665 non-null    int64
#  4   title               665 non-null    object
#  5   hits                665 non-null    int64
#  6   summary             665 non-null    object
#  7   is_priority         62 non-null     object
#  8   category_id         617 non-null    float64
#  9   category_desc       617 non-null    object
#  10  amsl                0 non-null      float64
#  11  amsl_unit           0 non-null      float64
#  12  org_title           665 non-null    object
#  13  org_content_id      665 non-null    int64
#  14  addresses_count     665 non-null    int64
#  15  locality            595 non-null    object
#  16  region              665 non-null    object
#  17  postalcode          659 non-null    float64
#  18  primary_loc         0 non-null      float64
#  19  display_url         665 non-null    object
#  20  recurrence_type     665 non-null    object
#  21  hours               665 non-null    int64
#  22  created_date        665 non-null    object
#  23  last_modified_date  665 non-null    object
#  24  start_date_date     665 non-null    object
#  25  end_date_date       665 non-null    object
#  26  status              665 non-null    object
#  27  Latitude            0 non-null      float64
#  28  Longitude           0 non-null      float64
#  29  Community Board     0 non-null      float64
#  30  Community Council   0 non-null      float64
#  31  Census Tract        0 non-null      float64
#  32  BIN                 0 non-null      float64
#  33  BBL                 0 non-null      float64
#  34  NTA                 0 non-null      float64
# dtypes: float64(13), int64(8), object(14)
# memory usage: 182.0+ KB

# %%
# Check how many values are missing in the category_desc column
volunteer.isna().sum()
# Out:
# opportunity_id          0
# content_id              0
# vol_requests            0
# event_time              0
# title                   0
# hits                    0
# summary                 0
# is_priority           603
# category_id            48
# category_desc          48
# amsl                  665
# amsl_unit             665
# org_title               0
# org_content_id          0
# addresses_count         0
# locality               70
# region                  0
# postalcode              6
# primary_loc           665
# display_url             0
# recurrence_type         0
# hours                   0
# created_date            0
# last_modified_date      0
# start_date_date         0
# end_date_date           0
# status                  0
# Latitude              665
# Longitude             665
# Community Board       665
# Community Council     665
# Census Tract          665
# BIN                   665
# BBL                   665
# NTA                   665
# dtype: int64

# %%
volunteer.category_desc.isna().sum()
# Out:
# 48

# %%
# Subset the volunteer dataset
volunteer_subset = volunteer[volunteer.category_desc.notnull()]

# %%
# Print out the shape of the subset
volunteer_subset.shape
# Out:
# (617, 35)

# %%
volunteer_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 617 entries, 1 to 664
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   opportunity_id      617 non-null    int64
#  1   content_id          617 non-null    int64
#  2   vol_requests        617 non-null    int64
#  3   event_time          617 non-null    int64
#  4   title               617 non-null    object
#  5   hits                617 non-null    int64
#  6   summary             617 non-null    object
#  7   is_priority         62 non-null     object
#  8   category_id         617 non-null    float64
#  9   category_desc       617 non-null    object
#  10  amsl                0 non-null      float64
#  11  amsl_unit           0 non-null      float64
#  12  org_title           617 non-null    object
#  13  org_content_id      617 non-null    int64
#  14  addresses_count     617 non-null    int64
#  15  locality            552 non-null    object
#  16  region              617 non-null    object
#  17  postalcode          612 non-null    float64
#  18  primary_loc         0 non-null      float64
#  19  display_url         617 non-null    object
#  20  recurrence_type     617 non-null    object
#  21  hours               617 non-null    int64
#  22  created_date        617 non-null    object
#  23  last_modified_date  617 non-null    object
#  24  start_date_date     617 non-null    object
#  25  end_date_date       617 non-null    object
#  26  status              617 non-null    object
#  27  Latitude            0 non-null      float64
#  28  Longitude           0 non-null      float64
#  29  Community Board     0 non-null      float64
#  30  Community Council   0 non-null      float64
#  31  Census Tract        0 non-null      float64
#  32  BIN                 0 non-null      float64
#  33  BBL                 0 non-null      float64
#  34  NTA                 0 non-null      float64
# dtypes: float64(13), int64(8), object(14)
# memory usage: 173.5+ KB

# %% [markdown]
# - Remember that you can use boolean indexing to effectively subset DataFrames.

# %%
# All three of these types are present in the DataFrame.
volunteer.dtypes
# Out:
# opportunity_id          int64
# content_id              int64
# vol_requests            int64
# event_time              int64
# title                  object
# hits                    int64
# summary                object
# is_priority            object
# category_id           float64
# category_desc          object
# amsl                  float64
# amsl_unit             float64
# org_title              object
# org_content_id          int64
# addresses_count         int64
# locality               object
# region                 object
# postalcode            float64
# primary_loc           float64
# display_url            object
# recurrence_type        object
# hours                   int64
# created_date           object
# last_modified_date     object
# start_date_date        object
# end_date_date          object
# status                 object
# Latitude              float64
# Longitude             float64
# Community Board       float64
# Community Council     float64
# Census Tract          float64
# BIN                   float64
# BBL                   float64
# NTA                   float64
# dtype: object

# %%
volunteer.hits.head()
# Out:
# 0    737
# 1     22
# 2     62
# 3     14
# 4     31
# Name: hits, dtype: int64

# %%
# Use astype to convert between a variety of types.
volunteer["hits"] = volunteer['hits'].astype('int')

# %%
volunteer.hits.dtypes
# Out:
# dtype('int32')

# %%
# Both Emergency Prepardness and Environment occur less than 50 times
volunteer_subset.category_desc.value_counts()
# Out:
# Strengthening Communities    307
# Helping Neighbors in Need    119
# Education                     92
# Health                        52
# Environment                   32
# Emergency Preparedness        15
# Name: category_desc, dtype: int64

# %%
volunteer_X = volunteer_subset.drop("category_desc", axis=1)
volunteer_X
# Out:
#      opportunity_id  content_id  vol_requests  event_time  \
# 1              5008       37036             2           0
# 2              5016       37143            20           0
# 3              5022       37237           500           0
# 4              5055       37425            15           0
# 5              5056       37426            15           0
# ..              ...         ...           ...         ...
# 660            5640       50193             3           0
# 661            5218       38711            10           0
# 662            5541       47820             1           0
# 663            5398       40722             2           0
# 664            5507       44303             5           0
#
#                                                  title  hits  \
# 1                                         Web designer    22
# 2        Urban Adventures - Ice Skating at Lasker Rink    62
# 3    Fight global hunger and support women farmers ...    14
# 4                                        Stop 'N' Swap    31
# 5                                 Queens Stop 'N' Swap   135
# ..                                                 ...   ...
# 660          Volunteer for NYLAG's Food Stamps Project   197
# 661    Iridescent Science Studio Open House Volunteers   113
# 662                                  French Translator   145
# 663                  Marketing & Advertising Volunteer   330
# 664  Volunteer filmmakers to help Mayor's Office wi...   304
#
#                                                summary is_priority  \
# 1               Build a website for an Afghan business         NaN
# 2    Please join us and the students from Mott Hall...         NaN
# 3    The Oxfam Action Corps is a group of dedicated...         NaN
# 4    Stop 'N' Swap reduces NYC's waste by finding n...         NaN
# 5    Stop 'N' Swap reduces NYC's waste by finding n...         NaN
# ..                                                 ...         ...
# 660  Volunteers needed to file for fair hearings, d...         NaN
# 661  Come out to the South Bronx to help us hold ou...         NaN
# 662  Volunteer needed to translate written material...         NaN
# 663  World Cares Center is looking for individuals ...         NaN
# 664  Attention all filmmakers, producers, and edito...         NaN
#
#      category_id  amsl  ...      end_date_date    status  Latitude  Longitude  \
# 1            1.0   NaN  ...   February 01 2011  approved       NaN        NaN
# 2            1.0   NaN  ...    January 29 2011  approved       NaN        NaN
# 3            1.0   NaN  ...      March 31 2012  approved       NaN        NaN
# 4            4.0   NaN  ...   February 05 2011  approved       NaN        NaN
# 5            4.0   NaN  ...   February 12 2011  approved       NaN        NaN
# ..           ...   ...  ...                ...       ...       ...        ...
# 660          2.0   NaN  ...   November 15 2012  approved       NaN        NaN
# 661          1.0   NaN  ...      April 13 2011  approved       NaN        NaN
# 662          2.0   NaN  ...  September 01 2011  approved       NaN        NaN
# 663          1.0   NaN  ...        May 31 2012  approved       NaN        NaN
# 664          1.0   NaN  ...    October 06 2012  approved       NaN        NaN
#
#     Community Board Community Council   Census Tract  BIN BBL NTA
# 1               NaN                NaN           NaN  NaN NaN NaN
# 2               NaN                NaN           NaN  NaN NaN NaN
# 3               NaN                NaN           NaN  NaN NaN NaN
# 4               NaN                NaN           NaN  NaN NaN NaN
# 5               NaN                NaN           NaN  NaN NaN NaN
# ..              ...                ...           ...  ...  ..  ..
# 660             NaN                NaN           NaN  NaN NaN NaN
# 661             NaN                NaN           NaN  NaN NaN NaN
# 662             NaN                NaN           NaN  NaN NaN NaN
# 663             NaN                NaN           NaN  NaN NaN NaN
# 664             NaN                NaN           NaN  NaN NaN NaN
#
# [617 rows x 34 columns]

# %%
volunteer_y = volunteer_subset[["category_desc"]]
volunteer_y
# Out:
#                  category_desc
# 1    Strengthening Communities
# 2    Strengthening Communities
# 3    Strengthening Communities
# 4                  Environment
# 5                  Environment
# ..                         ...
# 660  Helping Neighbors in Need
# 661  Strengthening Communities
# 662  Helping Neighbors in Need
# 663  Strengthening Communities
# 664  Strengthening Communities
#
# [617 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
# Use stratified sampling to split up the dataset according to the volunteer_y dataset
X_train, X_test, y_train, y_test = train_test_split(volunteer_X, volunteer_y, stratify=volunteer_y)

# %%
y_train["category_desc"].value_counts()
# Out:
# Strengthening Communities    230
# Helping Neighbors in Need     89
# Education                     69
# Health                        39
# Environment                   24
# Emergency Preparedness        11
# Name: category_desc, dtype: int64

# %%
# Standardization is a preprocessing task performed on numerical, continuous data.

# %%
# Split the dataset and labels into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21092/1638635090.py in <module>
#       1 # Split the dataset and labels into training and test sets
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# NameError: name 'X' is not defined
