# %% [markdown]
# > Việc hợp nhất các cột có thể được thực hiện bằng phương thức concat, merge của pandas.

# %% [markdown]
# ## 1. Chuẩn bị dữ liệu

# %%
# Đọc file dữ liệu 'FoodPrice_in_Turkey.csv'
import pandas as pd
df=pd.read_csv('FoodPrice_in_Turkey.csv')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Xóa các dòng có thuộc tính ProductID trùng nhau, giữ lại bản ghi cuối cùng, giữ chỉ số ban đầu của các dòng
df=df.drop_duplicates(['ProductId'], keep='last')
df.head()
# Out:
#                  Place  ProductId                      ProductName  UmId  \
# 1011  National Average        176             Tea (green) - Retail    33
# 1318  National Average        212       Peas (green, dry) - Retail     5
# 1360  National Average        229            Apples (red) - Retail     5
# 1436  National Average        233  Cucumbers (greenhouse) - Retail     5
# 2064  National Average        384            Bread (pita) - Retail     5
#
#      UmName  Month  Year  Price
# 1011   Unit      3  2017   4.65
# 1318     KG      6  2015   3.29
# 1360     KG      3  2017   2.83
# 1436     KG      3  2017   4.24
# 2064     KG      3  2017   2.48

# %%
# Tách file chứa thông tin sản phẩm
df_pro = df.loc[:,['ProductId','ProductName','UmId','UmName']]
df_pro.head()
# Out:
#       ProductId                      ProductName  UmId UmName
# 1011        176             Tea (green) - Retail    33   Unit
# 1318        212       Peas (green, dry) - Retail     5     KG
# 1360        229            Apples (red) - Retail     5     KG
# 1436        233  Cucumbers (greenhouse) - Retail     5     KG
# 2064        384            Bread (pita) - Retail     5     KG

# %%
# Tách file chứa thông tin giá
df_pri = df.loc[:,['ProductId','Place','Month','Year','Price']]
df_pri.head()
# Out:
#       ProductId             Place  Month  Year  Price
# 1011        176  National Average      3  2017   4.65
# 1318        212  National Average      6  2015   3.29
# 1360        229  National Average      3  2017   2.83
# 1436        233  National Average      3  2017   4.24
# 2064        384  National Average      3  2017   2.48

# %%
# Tách file chứa thông tin giá với số dòng từ bản ghi 10 đến 20
df_pri10 = df.loc[10:20,['ProductId','Place','Month','Year','Price']]
df_pri10
# Out:
# Empty DataFrame
# Columns: [ProductId, Place, Month, Year, Price]
# Index: []

# %% [markdown]
# ## 2. Ghép các cột từ các file

# %%
df1=pd.merge(df_pro,df_pri, on='ProductId')
df1.head()
# Out:
#    ProductId                      ProductName  UmId UmName             Place  \
# 0        176             Tea (green) - Retail    33   Unit  National Average
# 1        212       Peas (green, dry) - Retail     5     KG  National Average
# 2        229            Apples (red) - Retail     5     KG  National Average
# 3        233  Cucumbers (greenhouse) - Retail     5     KG  National Average
# 4        384            Bread (pita) - Retail     5     KG  National Average
#
#    Month  Year  Price
# 0      3  2017   4.65
# 1      6  2015   3.29
# 2      3  2017   2.83
# 3      3  2017   4.24
# 4      3  2017   2.48

# %%
df2=pd.concat([df_pro,df_pri], axis=1)
df2.head()
# Out:
#       ProductId                      ProductName  UmId UmName  ProductId  \
# 1011        176             Tea (green) - Retail    33   Unit        176
# 1318        212       Peas (green, dry) - Retail     5     KG        212
# 1360        229            Apples (red) - Retail     5     KG        229
# 1436        233  Cucumbers (greenhouse) - Retail     5     KG        233
# 2064        384            Bread (pita) - Retail     5     KG        384
#
#                  Place  Month  Year  Price
# 1011  National Average      3  2017   4.65
# 1318  National Average      6  2015   3.29
# 1360  National Average      3  2017   2.83
# 1436  National Average      3  2017   4.24
# 2064  National Average      3  2017   2.48

# %%
df2=pd.concat([df_pro,df_pri,df_pri10], axis=1)
df2.head()
# Out:
#       ProductId                      ProductName  UmId UmName  ProductId  \
# 1011        176             Tea (green) - Retail    33   Unit        176
# 1318        212       Peas (green, dry) - Retail     5     KG        212
# 1360        229            Apples (red) - Retail     5     KG        229
# 1436        233  Cucumbers (greenhouse) - Retail     5     KG        233
# 2064        384            Bread (pita) - Retail     5     KG        384
#
#                  Place  Month  Year  Price  ProductId Place  Month  Year  \
# 1011  National Average      3  2017   4.65        NaN   NaN    NaN   NaN
# 1318  National Average      6  2015   3.29        NaN   NaN    NaN   NaN
# 1360  National Average      3  2017   2.83        NaN   NaN    NaN   NaN
# 1436  National Average      3  2017   4.24        NaN   NaN    NaN   NaN
# 2064  National Average      3  2017   2.48        NaN   NaN    NaN   NaN
#
#       Price
# 1011    NaN
# 1318    NaN
# 1360    NaN
# 1436    NaN
# 2064    NaN
